# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Choice: Refresh / Content Opportunity Scoring.
#
# Why: Websites host thousands of pages, making it impossible for humans to review them all manually. I intend to build a model that acts as a smart prioritization tool, identifying decaying pages so writers know exactly which content to update first to prevent traffic loss.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The Decision: Determining which web pages should be reviewed for content refresh or update to prevent traffic loss.
#
# The Action: The editorial team will review the top 50 pages prioritized by the model and assign the most urgent candidates to a writing team for remediation.
#
# Cost of a Wrong Call: A false negative (missing a decaying page) results in lost organic traffic and revenue. A false positive (flagging a healthy page) results in the inefficient allocation of limited editorial budget and writer time.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/SRINIVASRAOAMMANGOD/flyrank-internship.git
import os
os.chdir('flyrank-internship')
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Audit data metrics for project feasibility
total_pages = len(df)
decay_counts = df['trend_direction'].str.lower().eq('down').sum()
median_age = df['content_age_days'].median()

print(f"Total pages analyzed: {total_pages:,}")
print(f"Pages actively losing traffic: {decay_counts:,} ({decay_counts/total_pages:.1%})")
print(f"Median age of content: {median_age:.0f} days")
# Out:
# Cloning into 'flyrank-internship'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 119 (delta 35), reused 77 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.85 MiB | 23.63 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Total pages analyzed: 30,000
# Pages actively losing traffic: 16,262 (54.2%)
# Median age of content: 236 days

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim: This project provides a directional signal to assist editorial prioritization based on observed historical traffic drops.
#
# What I cannot claim: I cannot claim that updating the flagged content will guarantee traffic recovery, as this is an observational study and not a controlled causal experiment. I am not attempting to predict or reverse-engineer Google’s ranking algorithms.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
